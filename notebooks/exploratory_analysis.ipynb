# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# Load sample data (replace with your actual data path)
try:
    df = pd.read_csv('../data/raw/sample_data.csv')
    print("Data loaded successfully!")
    print(f"Shape: {df.shape}")
    print("\nFirst 5 rows:")
    display(df.head())
except FileNotFoundError:
    print("Data file not found. Please ensure your data is in data/raw/ directory")
# Out:
# Data loaded successfully!
# Shape: (7, 7)
#
# First 5 rows:
#    test_id  force_N  displacement_mm  temperature_C  stress_MPa  strain  \
# 0        1      100             0.50             25          50   0.002
# 1        2      150             0.75             26          75   0.003
# 2        3      200             1.00             24         100   0.004
# 3        4      250             1.25             25         125   0.005
# 4        5      300             1.50             27         150   0.006
#
#    failure_point
# 0              0
# 1              0
# 2              0
# 3              0
# 4              1
